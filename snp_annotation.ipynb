# %%
import pandas as pd

# %%
credible_set_df = pd.read_csv('/Users/krilowcn/Desktop/Projects/snpAnnotation/data/simplified/credible_set_T2D.IEP.eqtl.gz', sep='\t',compression='gzip')
# Out:
# /Users/krilowcn/anaconda3/envs/BINF/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
credible_set_df.head(10)
# Out:
#    #chr      start        end     var_id       PPA ref_allele alt_allele  \
# 0     1  117532789  117532790  rs1127215  0.999822          C          T
# 1     1  117532789  117532790  rs1127215  0.999822          C          T
# 2     1  117532789  117532790  rs1127215  0.999822          C          T
# 3     1  117532789  117532790  rs1127215  0.999822          C          T
# 4     1  117532789  117532790  rs1127215  0.999822          C          T
# 5     1  117532789  117532790  rs1127215  0.999822          C          T
# 6     1  117532789  117532790  rs1127215  0.999822          C          T
# 7     1  117532789  117532790  rs1127215  0.999822          C          T
# 8     1  117532789  117532790  rs1127215  0.999822          C          T
# 9     1  117532789  117532790  rs1127215  0.999822          C          T
#
#                         locus  pvalue_mrmega  log10bf_mrmega  ...  \
# 0  fmap.PTGFRN.chr1:117532790   3.915500e-17        13.89214  ...
# ...

# %%
# # Get column names
# column_names = credible_set_df.columns
# print(column_names)
# credible_set_df.dtypes
# for i in column_names:
#   print('{} is unique: {}'.format(i, df[i].is_unique))
# # Check the index values
# # credible_set_df.index.values

# # Check if a certain index exists
# '0' in credible_set_df.index.values

# # If index does not exist
# # df.set_index('column_name_to_use', inplace=True)

# %%
# import pyranges as pr
InsPIRE_Beta_Exons_eQTLs_Nominal_Pvalues_df = pd.read_csv('/Users/krilowcn/Desktop/Projects/snpAnnotation/data/simplified/InsPIRE_Beta_Exons_eQTLs_Nominal_Pvalues.bed', sep='\t')

# %%
InsPIRE_Beta_Exons_eQTLs_Nominal_Pvalues_df
# Out:
#            #chr      start          end       var_id  \
# 0          11.0   71385842   71385843.0  rs113129037
# 1          11.0   71386131   71386132.0   rs28637592
# 2          11.0   71386450   71386451.0  rs112988407
# 3          11.0   71386477   71386478.0   rs72477703
# 4          11.0   71386963   71386964.0    rs7108275
# ...         ...        ...          ...          ...
# 665734792   2.0  108681308  108681309.0    rs6542748
# 665734793   2.0  108681914  108681915.0    rs1318242
# 665734794   2.0  108682926  108682927.0    rs6739428
# 665734795   2.0  108683510  108683511.0     rs832656
# 665734796   NaN         -1          NaN          NaN
#
#                                    BetaExonExonID  BetaExonEqtl_Pvalue  \
# 0            ENSG00000186642.11_72287185_72288638             0.884944
# 1            ENSG00000186642.11_72287185_72288638             0.872842
# 2            ENSG00000186642.11_72287185_72288638             0.565278
# ...
