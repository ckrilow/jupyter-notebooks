# %%
import plotly.graph_objs as go
import pandas as pd
from plotly.offline import iplot
import numpy as np
import statistics

# %%
e7_t01_rawCount_data = pd.read_csv("/Users/krilowcn/Desktop/Projects/GSIS/data/normalizedData/200613_E7_logNorm/200613_T01_logNorm.csv.gz", sep=",") #pandas DataFrame
# e7_t02_rawCount_data = pd.read_csv("/Users/krilowcn/Desktop/Projects/GSIS/data/normalizedData/200613_E7_logNorm/200613_T02_logNorm.csv.gz", sep=",") #pandas DataFrame
cell_types = pd.read_csv("/Users/krilowcn/Desktop/Projects/GSIS/data/normalizedData/200613_E7_logNorm/200613_E7_cell_type.txt", sep="\t") #pandas DataFrame for cell types

cell_type_row = pd.DataFrame({'Unnamed: 0':['cellType']})
e7_t01_rawCount_data = pd.concat([cell_type_row, e7_t01_rawCount_data]).reset_index(drop = True) #adding cell_type row to dataframe, to use later in plots
e7_t01_rawCount_data.replace(np.NaN, ' ', inplace=True)


cell_types_list = ['Alpha','Beta','Delta','Gamma','Epsilon'] #the cell types of interest for this work
cell_types = cell_types[cell_types['CellType'].isin(cell_types_list)] # parsing sampele type list, to only contain the cell types of interest
cell_types.reset_index(drop=True, inplace=True)
e7_t01_rawCount_data.replace(' ', np.NaN, inplace=True)
e7_t01_rawCount_data.head(-25)
# Out:
#       Unnamed: 0  AAACCTGAGCTTTGGT-1  AAACCTGGTAAATACG-1  AAACCTGGTAGCCTAT-1  \
# 0       cellType                 NaN                 NaN                 NaN
# 1         TSPAN6            0.000000            0.000000            0.423038
# 2           DPM1            0.000000            0.617793            0.423038
# 3            FGR            0.000000            0.000000            0.000000
# 4            CFH            0.000000            0.000000            0.000000
# ...          ...                 ...                 ...                 ...
# 9933       ORAI1            0.000000            0.000000            0.000000
# 9934      CCL4L2            1.960875            0.000000            0.000000
# 9935      CCL3L1            0.627125            0.000000            0.000000
# 9936  AC011043.1            0.000000            0.090737            0.000000
# 9937       DACH1            0.000000            0.173922            0.423038
#
# ...

# %%
#acces only samples from replicate T02 and celltype = 'Alpha' and create new dataframe
# cell_types_updated = cell_types.loc[(cell_types['SampleID'] == 'T02') & (cell_types['CellType'] == 'Alpha')] 
cell_types_updated = cell_types.loc[(cell_types['SampleID'] == 'T01')] 

counter =0

# #iterating the columns to find sample type
for index, row in cell_types_updated.iterrows():
    for col_name in e7_t01_rawCount_data.columns: 
        index_no = e7_t01_rawCount_data.columns.get_loc(col_name)
        if col_name == row["CellID"]:
            counter +=1
            print("Match Found:" + row["CellID"] + ", Dataframe Information:" + col_name + ", Location:" + str(index_no) + ",Celltype:" + row["CellType"])
#             print(e7_t01_rawCount_data.iat[0,index_no])
            e7_t01_rawCount_data.iat[0,index_no] = row['CellType']

    
# print("Alpha Cell Count: " + str(counter)) #counter that shows the number of Alpha cell type matches
# Out:
# Match Found:AAACCTGGTAGCCTAT-1, Dataframe Information:AAACCTGGTAGCCTAT-1, Location:3,Celltype:Alpha
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a2451b2b1cf7> in <module>
#      13             print("Match Found:" + row["CellID"] + ", Dataframe Information:" + col_name + ", Location:" + str(index_no) + ",Celltype:" + row["CellType"])
#      14 #             print(e7_t01_rawCount_data.iat[0,index_no])
# ---> 15             e7_t01_rawCount_data.iat[0,index_no] = row['CellType']
#      16
#      17
#
# ~/anaconda3/envs/BINF/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2040             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2041
# -> 2042         self.obj._set_value(*key, value=value, takeable=self._takeable)
#    2043
#    2044
#
# ...

# %%
e7_t02_rawCount_data.replace(' ', np.NaN, inplace=True)

# e7_t02_rawCount_data = e7_t02_rawCount_data.dropna(axis=1)

e7_t02_rawCount_data.head(-10)

# e7_t02_rawCount_data.to_csv("/Users/krilowcn/Desktop/Projects/GSIS/data/normalizedData/200613_E7_logNorm/200613_T02_logNorm_alpha_cells.csv", index=False, sep=',')
# Out:
#       Unnamed: 0  AAACCTGAGCTTTGGT-1  AAACCTGGTAAATACG-1  AAACCTGGTAGCCTAT-1  \
# 0       cellType                 NaN                 NaN                 NaN
# 1         TSPAN6                 0.0            0.000000            0.423038
# 2           DPM1                 0.0            0.617793            0.423038
# 3            FGR                 0.0            0.000000            0.000000
# 4            CFH                 0.0            0.000000            0.000000
# ...          ...                 ...                 ...                 ...
# 9948      GGNBP2                 0.0            0.565228            0.423038
# 9949      DHRS11                 0.0            0.090737            0.000000
# 9950       ACACA                 0.0            0.090737            0.000000
# 9951        MRM1                 0.0            0.000000            0.000000
# 9952  AC007325.4                 0.0            0.000000            0.000000
#
# ...

# %%
e7_t02_rawCount_data.head(-25)
# Out:
#        Unnamed: 0 AAACCTGCATCTCCCA-1 AAACCTGTCAGTTGAC-1 AAACGGGTCGGCGCAT-1  \
# 0        cellType              Alpha              Alpha              Alpha
# 1          TSPAN6                  0                  0                  0
# 2            DPM1           0.701501                  0            0.56312
# 3             FGR                  0                  0                  0
# 4             CFH                  0                  0                  0
# ...           ...                ...                ...                ...
# 10206      CCL3L1                  0                  0                  0
# 10207  AC011043.1                  0           0.543953                  0
# 10208     PIP4K2B                  0                  0                  0
# 10209       DACH1           0.291868                  0            0.56312
# 10210        F8A1                  0                  0                  0
#
#       AAACGGGTCTGAGTGT-1 AAAGATGAGGATGTAT-1 AAAGATGGTGATGTCT-1  \
# ...

# %%
e7_t02_rawCount_data_aplha_cells = pd.read_csv("/Users/krilowcn/Desktop/Projects/GSIS/data/normalizedData/200613_E7_logNorm/200613_T02_logNorm_alpha_cells.csv", sep=",") #pandas DataFrame
e7_t02_rawCount_data_aplha_cells.head(-25)
# Out:
# /Users/krilowcn/anaconda3/envs/BINF/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning:
#
# ...
